# %% [markdown]
# <a href="https://colab.research.google.com/github/TurkuNLP/textual-data-analysis-course/blob/main/test_nlp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Question Answering
#
# * Easy to run with standard tools
# * Models default to English
# * But you can find many more at the HuggingFace model repository

# %%
# !pip install transformers

# %%
import transformers
#this will load a default English model trained for Question Answering
pipe=transformers.pipeline("question-answering")
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-cased-distilled-squad and revision 564e9b5 (https://huggingface.co/distilbert/distilbert-base-cased-distilled-squad).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/473 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/261M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/49.0 [00:00<?, ?B/s]
# ...

# %%
context="""Forbes has ranked Finland as the world's sixth best country for business in its annual list,
the Best Countries for Business. Finland is the best country in the world in terms of individual and property rights,
the  second best in terms of the innovation landscape and the third best in terms of corruption, the American business magazine lists."""

pipe(question="What is Finland's rank in terms of corruption?", context=context)
# Out:
# {'score': 0.5244108438491821, 'start': 274, 'end': 279, 'answer': 'third'}

# %% [markdown]
# # Question Answering tasks
#
# ## Task 1
#
# * Pick a few short paragraphs from your favorite source
# * Come up with a few questions with an answer in the text and test the QA model
# * How well did the model fare?
# * Was it easy to come up with non-trivial questions? Think whether this approach is a good approach to build a QA dataset.
#
# ## Task 2
#
# * If you can access ChatGPT, ask it the same questions. Did it succeed?
#
# ## Task 3
#
# * Explore the Hugging Face model repository. https://huggingface.co/models
# * Try some of the QA models for a language of your interest. Can you find any? Below you can see a model for Finnish.

# %% [markdown]
# # Task 1 and 2 Solutions
# ### A Sample Paragraph as Context

# %%
context = "Åbo Akademi University (ÅAU) is small enough for our professors to be easily accessible.\
At the same time, we offer a wide range of educational options. It means that you will be provided \
with individual guidance and the opportunity to tailor your studies for a unique degree. And, thanks \
to our networks of international contacts all over the world, you will be able to conduct part of your studies abroad.\
We are the only university in Finland that has been specifically established to serve the needs of a minority group,\
that is, the Swedish speaking language minority. Subsequently, this purpose has been laid down in legislation.\
A research profile focusing on minorities is thus both natural and unique at a national level.\
The Swedish-speaking minority in Finland has traditionally formed the core of our expertise in minorities.\
However, current Åbo Akademi University research on minorities builds on a broad understanding of minority\
research and its focus extends to minorities on a global level and encompasses both old and new minorities\
(migrants and refugees) as well as the processes of minoritization and resistance they engender. \
Four thematic areas form our research strengths and topics: Equal rights, discrimination and democracy;\
Minority identities and culture; Minoritization processes and minority positions in history; \
Culturally and linguistically responsive teacher education.\
Our minority profile strives to explore the concept of a minority and minority \
positions from the novel angle as generating new narratives of inclusion and belonging. \
This multidimensional approach and focus as regards minority issues makes the ÅAU minority \
profile stand out in relation to other universities in Finland, and indeed internationally. \
It creates multiple possibilities for collaboration, and for making important contributions \
to exposing and challenging mechanisms and policies of marginalization and exclusion in society.\
The minority research profile aims at developing the Åbo Akademi University into a world-leading centre\
for minority studies and research through cutting-edge research, teaching, and active societal engagement.\
More information about researchers and research projects linked to the profile, as well as new publications,\
can be found on the Åbo Akademi University database.\
Åbo Akademi University now collects donations for our strategic research profiles. \
By donating to Minority Research you support our research in difference and the roots \
of inequality and help us in our strive to address injustices and promote basic and human \
rights for all in order to build more sustainable societies."

# %% [markdown]
# ### Some Trivial Questions and Comparison to ChatGPT Answers
#
#
# #### Question 1
# `Question`: What advantage do student get due to Abo Akademi's networks of international contacts?
#
#
# `Answer`: You will be able to conduct part of your studies abroad.

# %%
pipe(question="What advantage do student get due to Abo Akademi's networks of international contacts?",
     context=context)
# Out:
# {'score': 0.6644205451011658,
#  'start': 350,
#  'end': 405,
#  'answer': 'you will be able to conduct part of your studies abroad'}

# %% [markdown]
# `ChatGPT Answer`: Students at Åbo Akademi University benefit from the university's networks of international contacts by having the opportunity to conduct part of their studies abroad. This exposure allows them to gain global academic and cultural experiences, expand their professional networks, and enhance their career prospects by engaging with diverse learning environments.

# %% [markdown]
# #### Question 2
# `Question`: Which one is the only university in Finland that specificially serves minority?
#
# `Answer`: Åbo Akademi University

# %%
pipe(question="Which one is the only university in Finland that specificially serves minority?",
     context=context)
# Out:
# {'score': 0.8629921674728394,
#  'start': 0,
#  'end': 22,
#  'answer': 'Åbo Akademi University'}

# %% [markdown]
# `ChatGPT Answer`: Åbo Akademi University (ÅAU) is the only university in Finland that has been specifically established to serve the needs of a minority group, namely the Swedish-speaking language minority. This purpose has even been laid down in legislation.

# %% [markdown]
# #### Question 3
# `Question`: How can you help to address injustices and promote basic human rights to all?
#
# `Answer`: By donating to minority research at Åbo Akademi University.

# %%
pipe(question="How can you help to address injustices and promote basic human rights to all?",
     context=context)
# Out:
# {'score': 0.42755478620529175,
#  'start': 2386,
#  'end': 2418,
#  'answer': 'By donating to Minority Research'}

# %% [markdown]
# `ChatGPT Answer:` By donating to Minority Research at Åbo Akademi University, you support research on difference and the roots of inequality, helping to address injustices and promote basic and human rights for all. This research contributes to exposing and challenging mechanisms and policies of marginalization and exclusion, ultimately working towards more sustainable societies.

# %% [markdown]
# ### Some Non-Trivial Questions and Comparison to ChatGPT Answers
#
# `Question`: How does Åbo Akademi University’s broad approach to minority research, which includes both historical and contemporary minorities (such as migrants and refugees), contribute to shaping more inclusive policies and societal structures on a global scale?
#
# `Answer`: By exploring the concept of a minority and minority positions from the novel angle as generating new narratives of inclusion and belonging.

# %%
pipe(question="How does Åbo Akademi University’s broad approach to minority research, \
              which includes both historical and contemporary minorities (such as migrants and refugees), \
              contribute to shaping more inclusive policies and societal structures on a global scale?",
     context=context)
# Out:
# {'score': 0.10958440601825714,
#  'start': 32,
#  'end': 87,
#  'answer': 'small enough for our professors to be easily accessible'}

# %% [markdown]
# `ChatGPT Answer`: Åbo Akademi University’s broad approach to minority research contributes to shaping more inclusive policies and societal structures by exploring minority positions from a novel angle, generating new narratives of inclusion and belonging, and exposing and challenging mechanisms and policies of marginalization and exclusion.

# %% [markdown]
# # Results from Task 1 and 2
# - The QA model from hugging face fared perfectly when asked simple and trivial questions from the given context. It's performance was almost equal to the ChatGPT model. The only difference was that GPT model was able to present the answer in a complete manner due to its text generation capability. However, QA model was only able to extract the answer from the context.
# - For non-trivial question or a question that required critical thinking, knowledge synthesis, and so on, the QA model did not perform up to the mark. In fact, it got the answer completely wrong, whereas GPT model coutld perfectly answer the question.
# - So, building dataset in this way will be effective if the task is to develop a model to answer factual and extractive questions well. It may also answer slightly rephrased questions.
# - However, as seen in the comparison with GPT models, this way of training models fails in deep reasoning or if the answer is not explicitly in the context.

# %% [markdown]
# # Task 3
# In this task, I have instantiated a Bengali model. However, for the Bengali model, I have to download the tokenizer too as different languages are tokenized in different ways.

# %%
from transformers import AutoModelForQuestionAnswering, AutoTokenizer, pipeline

model_name = "sagorsarker/mbert-bengali-tydiqa-qa"
model = AutoModelForQuestionAnswering.from_pretrained(model_name)
tokenizer = AutoTokenizer.from_pretrained(model_name)
# Out:
# config.json:   0%|          | 0.00/819 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/667M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/298 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/872k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]

# %%
nlp = pipeline('question-answering', model=model_name, tokenizer=model_name)
qa_input = {
    'question': 'মাস্টারদা সূর্যকুমার সেনের বাবার নাম কী ছিল?',
    'context': 'সূর্য সেন ১৮৯৪ সালের ২২ মার্চ চট্টগ্রামের রাউজান থানার নোয়াপাড়ায় অর্থনৈতিক ভাবে অস্বচ্ছল পরিবারে জন্মগ্রহণ করেন। তাঁর পিতার নাম রাজমনি সেন এবং মাতার নাম শশী বালা সেন। রাজমনি সেনের দুই ছেলে আর চার মেয়ে। সূর্য সেন তাঁদের পরিবারের চতুর্থ সন্তান। দুই ছেলের নাম সূর্য ও কমল। চার মেয়ের নাম বরদাসুন্দরী, সাবিত্রী, ভানুমতী ও প্রমিলা। শৈশবে পিতা মাতাকে হারানো সূর্য সেন কাকা গৌরমনি সেনের কাছে মানুষ হয়েছেন। সূর্য সেন ছেলেবেলা থেকেই খুব মনোযোগী ভাল ছাত্র ছিলেন এবং ধর্মভাবাপন্ন গম্ভীর প্রকৃতির ছিলেন।'
}

result = nlp(qa_input)
print(result)
# Out:
# Device set to use cuda:0
# {'score': 0.8070713877677917, 'start': 131, 'end': 141, 'answer': 'রাজমনি সেন'}

# %% [markdown]
# # Results from Task 3
# The Bengali QA model was able to answer the question perfectly. It was even able to answer slightly rephrased question. For example, I asked the name of the father of some person in the context. However, I used a different synonym of the word 'father' in the question, and it was able to answer.

# %% [markdown]
# # Summarization
#
# * text2text problem
#
# ## Task 1
#
# * Pick a text of your liking, and test the summarization pipeline below on it. Does it do a decent job?
#
# ## Task 2
#
# * The pipeline accepts a `min_length` and `max_length` parameters when you run it, try to adjust these to various lengths and see if the model comes up with a reasonable summarization choice.
#
# ## Task 3
#
# * Explore the Hugging Face models repository and experiment with summarization models for other languages of your choice. Do they exist? Do they work?
#
# ## Task 4
#
# * If you can access ChatGPT, try to have it summarize a piece of text. Did it work as you expected? Were you able to control the length effectively? How about other languages?

# %% [markdown]
# ### Task 1 Solution

# %%
paragraph = """
The global energy crisis has been a growing concern over the past few decades,
driven by an increasing demand for power, dwindling fossil fuel reserves, and the
environmental impact of traditional energy sources. Countries worldwide are
investing in renewable energy solutions such as solar, wind, and hydroelectric
power to address these issues. However, challenges remain, including the intermittency
of renewable energy sources, the high cost of energy storage, and the need for
modernized energy infrastructure. Governments and private sectors are collaborating
to develop innovative battery technologies, improve grid efficiency, and establish
policies that incentivize clean energy adoption. Additionally, nuclear energy is
being reconsidered as a potential solution, despite concerns regarding waste disposal
and safety risks. As the world moves toward a more sustainable energy future,
balancing economic growth, technological innovation, and environmental conservation
remains a critical challenge.
"""

# %%
pipe = transformers.pipeline("summarization")
# Out:
# No model was supplied, defaulted to sshleifer/distilbart-cnn-12-6 and revision a4f8f3e (https://huggingface.co/sshleifer/distilbart-cnn-12-6).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# config.json:   0%|          | 0.00/1.80k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/1.22G [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.22G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Device set to use cuda:0

# %%
pipe(paragraph)
# Out:
# [{'summary_text': ' The global energy crisis has been a growing concern over the past few decades . Countries worldwide are investing in renewable energy solutions such as solar, wind, and hydroelectric power to address these issues . Nuclear energy is being reconsidered as a potential solution, despite concerns regarding waste disposal and safety risks .'}]

# %% [markdown]
# # Result of Task 1
# The summarization model was able to extract 3 key sentences from the paragraph without any modification or paraphrasing. So, it is difficult to say that the model has done a decent job in summarization.

# %% [markdown]
# ### Task 2 Solution

# %%
pipe(paragraph, min_length=150, max_length=150)
# Out:
# [{'summary_text': ' The global energy crisis has been a growing concern over the past few decades, driven by an increasing demand for power, dwindling fossil fuel reserves, and the impact of traditional energy sources . Countries worldwide are investing in renewable energy solutions such as solar, wind, and hydroelectric power to address these issues . However, challenges remain, including the intermittency of renewable energy sources and the high cost of energy storage . Governments and private sectors are collaborating to develop innovative battery technologies, improve grid efficiency, and establish  policies that incentivize clean energy adoption . Nuclear energy is reconsidering as a potential solution, despite concerns regarding waste disposal and safety risks . As the world moves toward a more sustainable energy future, balancing economic growth, technological innovation,'}]

# %% [markdown]
# # Results from Task 2
# - The output remains the same even if I increase the `max_length` parameter.
# - To enforce a change, I had to increase the `min_length` parameter.
# - The last line of the summary is **"As the world moves toward a more sustainable energy future, balancing economic growth, technological innovation,".** It means that the model may not have actual summarization capability.
# - Finally, tuning `max_length` or `min_length` did not yield any improvement in quality of summary.

# %% [markdown]
# ### Task 3 Solution
#
# I tried to search for summarization models for the Bengali language. However, there was only one model.

# %%
from transformers import MT5ForConditionalGeneration, MT5Tokenizer

model_name = "tashfiq61/bengali-summarizer-mt5"
tokenizer = MT5Tokenizer.from_pretrained(model_name)
model = MT5ForConditionalGeneration.from_pretrained(model_name)
# Out:
# tokenizer_config.json:   0%|          | 0.00/19.3k [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/4.31M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/416 [00:00<?, ?B/s]
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'T5Tokenizer'.
# The class this function is called from is 'MT5Tokenizer'.
# config.json:   0%|          | 0.00/967 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.20G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/142 [00:00<?, ?B/s]

# %%
def summarize(text):
    inputs = tokenizer.encode("summarize: " + text, return_tensors="pt", max_length=512, truncation=True)
    summary_ids = model.generate(inputs, max_length=150, min_length=40, length_penalty=2.0, num_beams=4, early_stopping=True)
    return tokenizer.decode(summary_ids[0], skip_special_tokens=True)

# %%
bn_text = """
বিশ্বব্যাপী জ্বালানি সংকট গত কয়েক দশক ধরে ক্রমবর্ধমান উদ্বেগের কারণ হয়ে দাঁড়িয়েছে, যা মূলত শক্তির ক্রমবর্ধমান চাহিদা,
জীবাশ্ম জ্বালানির সীমিত মজুত এবং পরিবেশগত প্রভাবের কারণে সৃষ্টি হয়েছে। এই চ্যালেঞ্জ মোকাবিলায় বিভিন্ন দেশ নবায়নযোগ্য
শক্তির উৎস যেমন সৌরশক্তি, বায়ুশক্তি এবং জলবিদ্যুৎ ব্যবহারের দিকে মনোযোগ দিচ্ছে। তবে, নবায়নযোগ্য শক্তির অস্থিরতা,
শক্তি সংরক্ষণের উচ্চ ব্যয় এবং আধুনিক শক্তি অবকাঠামোর অভাবের মতো সমস্যা এখনো বিদ্যমান। সরকার এবং বেসরকারি
সংস্থাগুলো উন্নত ব্যাটারি প্রযুক্তি, বিদ্যুৎ গ্রিডের দক্ষতা বৃদ্ধি এবং নবায়নযোগ্য শক্তিকে উৎসাহিত করার জন্য নীতি প্রণয়নের
ক্ষেত্রে একত্রে কাজ করছে। পাশাপাশি, পারমাণবিক শক্তি আবারও বিকল্প সমাধান হিসাবে বিবেচিত হচ্ছে, যদিও তেজস্ক্রিয় বর্জ্য
ব্যবস্থাপনা এবং নিরাপত্তা ঝুঁকি নিয়ে উদ্বেগ রয়েছে। বিশ্ব যদি টেকসই জ্বালানি ব্যবস্থার দিকে এগিয়ে যেতে চায়, তবে অর্থনৈতিক
উন্নয়ন, প্রযুক্তিগত উদ্ভাবন এবং পরিবেশ সংরক্ষণের মধ্যে ভারসাম্য রক্ষা করাই সবচেয়ে বড় চ্যালেঞ্জ।
"""

# %%
print(summarize(bn_text))
# Out:
# বাংলাদেশে জ্বালানি সংকট গত কয়েক দশক ধরে ক্রমবর্ধমান উদ্বেগ রয়েছে, যা ক্রমবর্ধমান উদ্বেগ রয়েছে।

# %% [markdown]
# # Results of Task 3
# - There is only $1$ text summarization model for the Bengali language.
# - It does not work at all. It seems that it just tries to extract some sentenes, or even just part of sentence, without understanding whether they make sense or not.

# %% [markdown]
# ### Task 4 Solution
#
# #### Actual Paragraph
# The global energy crisis has been a growing concern over the past few decades,
# driven by an increasing demand for power, dwindling fossil fuel reserves, and the
# environmental impact of traditional energy sources. Countries worldwide are
# investing in renewable energy solutions such as solar, wind, and hydroelectric
# power to address these issues. However, challenges remain, including the intermittency
# of renewable energy sources, the high cost of energy storage, and the need for
# modernized energy infrastructure. Governments and private sectors are collaborating
# to develop innovative battery technologies, improve grid efficiency, and establish
# policies that incentivize clean energy adoption. Additionally, nuclear energy is
# being reconsidered as a potential solution, despite concerns regarding waste disposal
# and safety risks. As the world moves toward a more sustainable energy future,
# balancing economic growth, technological innovation, and environmental conservation
# remains a critical challenge.
#
# #### ChatGPT Summary without Word Limit
# The global energy crisis, driven by rising demand, dwindling fossil fuels, and environmental concerns, has led countries to invest in renewable sources like solar, wind, and hydroelectric power. However, challenges such as energy intermittency, high storage costs, and outdated infrastructure persist. Governments and private sectors are collaborating on battery innovations, grid efficiency, and clean energy policies. Nuclear energy is also being reconsidered despite safety concerns. Achieving a sustainable energy future requires balancing economic growth, technological advancements, and environmental protection.
#
# #### ChatGPT Summary With 50 Words Limitation
# The global energy crisis stems from rising demand, dwindling fossil fuels, and environmental concerns. Countries invest in renewables, but challenges like energy intermittency and high storage costs persist. Governments and industries focus on battery innovations, grid efficiency, and clean energy policies. Nuclear energy is reconsidered, balancing sustainability with economic and technological progress.
#
# #### Huggingface Model Summary
# The global energy crisis has been a growing concern over the past few decades . Countries worldwide are investing in renewable energy solutions such as solar, wind, and hydroelectric power to address these issues . Nuclear energy is being reconsidered as a potential solution, despite concerns regarding waste disposal and safety risks .
#
# #### Results
# - ChatGPT could response gracefully to changing word limits, whereas the huggingface summarizer could not.
# - ChatGPT could actually summarize and rephrase the content that the huggingface summarizer.

# %% [markdown]
# #### Actual Bengali Paragraph
# বিশ্বব্যাপী জ্বালানি সংকট গত কয়েক দশক ধরে ক্রমবর্ধমান উদ্বেগের কারণ হয়ে দাঁড়িয়েছে, যা মূলত শক্তির ক্রমবর্ধমান চাহিদা,
# জীবাশ্ম জ্বালানির সীমিত মজুত এবং পরিবেশগত প্রভাবের কারণে সৃষ্টি হয়েছে। এই চ্যালেঞ্জ মোকাবিলায় বিভিন্ন দেশ নবায়নযোগ্য
# শক্তির উৎস যেমন সৌরশক্তি, বায়ুশক্তি এবং জলবিদ্যুৎ ব্যবহারের দিকে মনোযোগ দিচ্ছে। তবে, নবায়নযোগ্য শক্তির অস্থিরতা,
# শক্তি সংরক্ষণের উচ্চ ব্যয় এবং আধুনিক শক্তি অবকাঠামোর অভাবের মতো সমস্যা এখনো বিদ্যমান। সরকার এবং বেসরকারি
# সংস্থাগুলো উন্নত ব্যাটারি প্রযুক্তি, বিদ্যুৎ গ্রিডের দক্ষতা বৃদ্ধি এবং নবায়নযোগ্য শক্তিকে উৎসাহিত করার জন্য নীতি প্রণয়নের
# ক্ষেত্রে একত্রে কাজ করছে। পাশাপাশি, পারমাণবিক শক্তি আবারও বিকল্প সমাধান হিসাবে বিবেচিত হচ্ছে, যদিও তেজস্ক্রিয় বর্জ্য
# ব্যবস্থাপনা এবং নিরাপত্তা ঝুঁকি নিয়ে উদ্বেগ রয়েছে। বিশ্ব যদি টেকসই জ্বালানি ব্যবস্থার দিকে এগিয়ে যেতে চায়, তবে অর্থনৈতিক
# উন্নয়ন, প্রযুক্তিগত উদ্ভাবন এবং পরিবেশ সংরক্ষণের মধ্যে ভারসাম্য রক্ষা করাই সবচেয়ে বড় চ্যালেঞ্জ।
#
# #### ChatGPT Summary Without Word Limit
# বিশ্বব্যাপী জ্বালানি সংকটের মূল কারণ হলো ক্রমবর্ধমান শক্তি চাহিদা, জীবাশ্ম জ্বালানির সংকট ও পরিবেশগত প্রভাব। দেশগুলো নবায়নযোগ্য শক্তিতে বিনিয়োগ করলেও সংরক্ষণ ব্যয় ও অবকাঠামোগত সমস্যা রয়ে গেছে। সরকার ও বেসরকারি খাত নতুন প্রযুক্তি ও নীতিমালা উন্নয়নে কাজ করছে, পাশাপাশি পারমাণবিক শক্তির সম্ভাবনাও বিবেচিত হচ্ছে।
#
# #### ChatGPT Summary With 20 Words Limitation
# জ্বালানি সংকট মোকাবিলায় দেশগুলো নবায়নযোগ্য ও পারমাণবিক শক্তিতে বিনিয়োগ করছে, তবে অবকাঠামো উন্নয়ন, ব্যাটারি সংরক্ষণ ও পরিবেশ সংরক্ষণ বড় চ্যালেঞ্জ।
#
# #### Results
# - ChatGPT was able to summarize Bengali text perfectly.
# - It responded gracefully to changing word limits.
# - It did not stop a sentence abruptly in the midway just like summarizer models from huggingface.
